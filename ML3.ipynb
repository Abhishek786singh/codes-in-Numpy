# %%
import pandas as pd
x=pd.DataFrame({"a":1,"b":2,"c":3},index=['p','q','r'])

# %%
print(x)
# Out:
#    a  b  c
# p  1  2  3
# q  1  2  3
# r  1  2  3

# %%
x=pd.DataFrame([[1,2,3],[3,4,2],[4,3,4]],columns=['a','b','c'],index=[1,2,3])

# %%
print(x)
# Out:
#    a  b  c
# 1  1  2  3
# 2  3  4  2
# 3  4  3  4

# %%
states =({'State' :['Gujarat', 'Tamil Nadu', ' Andhra', 'Karnataka',  'Kerala'], 'Population': [36, 44, 67,89,34],\
         'Language' :['Gujarati',  'Tamil', 'Telugu', 'Kannada', 'Malayalam']})
y=pd.DataFrame(states)
print(y)
# Out:
#   File "<ipython-input-14-c453b6df90a2>", line 1
#     states =({'State' :['Gujarat', 'Tamil Nadu', ' Andhra', 'Karnataka',  'Kerala'], 'Population': [36, 44, 67,89,34],         'Language' :['Gujarati',  'Tamil', 'Telugu', 'Kannada', 'Malayalam']})
#           ^
# SyntaxError: invalid character in identifier

# %%
u=pd.DataFrame({'x1':['a','b','c'],'x2':[1,2,3]})

# %%
u
# Out:
#   x1  x2
# 0  a   1
# 1  b   2
# 2  c   3

# %%
df1=pd.DataFrame({'a':[1,2,3],'b':[4,5,6]},index=['j','k','l'])

# %%
df1
# Out:
#    a  b
# j  1  4
# k  2  5
# l  3  6

# %%
import pandas as pd
p=pd.DataFrame({'a':[1,2,3],'b':[5,6,7],'c':[4,5,6]}
             , index=(5,6,7))
p
# Out:
#    a  b  c
# 5  1  5  4
# 6  2  6  5
# 7  3  7  6

# %%
p.a
# Out:
# 0    1
# 1    2
# 2    3
# Name: a, dtype: int64

# %%
p[['a','b']]
# Out:
#    a  b
# 5  1  5
# 6  2  6
# 7  3  7

# %%
#to convert frame to matrix
p.values
# Out:
# array([[1, 5, 4],
#        [2, 6, 5],
#        [3, 7, 6]], dtype=int64)

# %%
data=pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv')
data.head()#top 5 values
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data['TV'].min()
data['TV'].max()
# Out:
# 296.39999999999998

# %%
#x=feature
#y=dependent
x=data[['TV','radio','newspaper']]
#label
y=data[['sales']]
y.head(5)
# Out:
#    sales
# 0   22.1
# 1   10.4
# 2    9.3
# 3   18.5
# 4   12.9

# %%
y
# Out:
#      sales
# 0     22.1
# 1     10.4
# 2      9.3
# 3     18.5
# 4     12.9
# 5      7.2
# 6     11.8
# 7     13.2
# 8      4.8
# 9     10.6
# 10     8.6
# 11    17.4
# 12     9.2
# 13     9.7
# 14    19.0
# 15    22.4
# 16    12.5
# 17    24.4
# 18    11.3
# 19    14.6
# 20    18.0
# 21    12.5
# 22     5.6
# 23    15.5
# 24     9.7
# 25    12.0
# 26    15.0
# 27    15.9
# 28    18.9
# 29    10.5
# ..     ...
# 170    8.4
# 171   14.5
# 172    7.6
# 173   11.7
# 174   11.5
# 175   27.0
# 176   20.2
# 177   11.7
# 178   11.8
# 179   12.6
# 180   10.5
# 181   12.2
# 182    8.7
# 183   26.2
# 184   17.6
# 185   22.6
# 186   10.3
# 187   17.3
# 188   15.9
# 189    6.7
# 190   10.8
# 191    9.9
# 192    5.9
# 193   19.6
# 194   17.3
# 195    7.6
# 196    9.7
# 197   12.8
# 198   25.5
# 199   13.4
#
# [200 rows x 1 columns]

# %%
x
x.head(5)
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
x
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# 5      8.7   48.9       75.0
# 6     57.5   32.8       23.5
# 7    120.2   19.6       11.6
# 8      8.6    2.1        1.0
# 9    199.8    2.6       21.2
# 10    66.1    5.8       24.2
# 11   214.7   24.0        4.0
# 12    23.8   35.1       65.9
# 13    97.5    7.6        7.2
# 14   204.1   32.9       46.0
# 15   195.4   47.7       52.9
# 16    67.8   36.6      114.0
# 17   281.4   39.6       55.8
# 18    69.2   20.5       18.3
# 19   147.3   23.9       19.1
# 20   218.4   27.7       53.4
# 21   237.4    5.1       23.5
# 22    13.2   15.9       49.6
# 23   228.3   16.9       26.2
# 24    62.3   12.6       18.3
# 25   262.9    3.5       19.5
# 26   142.9   29.3       12.6
# 27   240.1   16.7       22.9
# 28   248.8   27.1       22.9
# 29    70.6   16.0       40.8
# ..     ...    ...        ...
# ...

# %%
import matplotlib.pyplot as plt
x=data['TV']
y=data['sales']
plt.scatter(x,y,color='#50ff00ff')
plt.show()

# %%
chips=pd.read_table('http://bit.ly/chiporders')
chips.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
chips.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39

# %%
chips.item_price.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#     751         try:
# --> 752             x = float(x)
#     753         except Exception:
#
# ...

# %%
chips.item_price.str.replace('$','')
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
# 5       10.98
# 6        1.69
# 7       11.75
# 8        9.25
# 9        9.25
# 10       4.45
# 11       8.75
# 12       8.75
# 13      11.25
# 14       4.45
# 15       2.39
# 16       8.49
# 17       8.49
# 18       2.18
# 19       8.75
# 20       4.45
# 21       8.99
# 22       3.39
# 23      10.98
# 24       3.39
# 25       2.39
# 26       8.49
# 27       8.99
# 28       1.09
# 29       8.49
#          ...
# 4592    11.75
# 4593    11.75
# 4594    11.75
# 4595     8.75
# 4596     4.45
# 4597     1.25
# 4598     1.50
# 4599     8.75
# 4600     4.45
# 4601     1.25
# 4602     9.25
# 4603     9.25
# 4604     8.75
# 4605     4.45
# 4606     1.25
# 4607    11.75
# 4608    11.25
# 4609     1.25
# 4610    11.75
# 4611    11.25
# 4612     9.25
# 4613     2.15
# 4614     1.50
# 4615     8.75
# 4616     4.45
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# ...

# %%
chips.item_price.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#     751         try:
# --> 752             x = float(x)
#     753         except Exception:
#
# ...

# %%
chip.item_price.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-9f7fa2883b10> in <module>()
# ----> 1 chip.item_price.mean()
#
# NameError: name 'chip' is not defined

# %%
chips.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
 chips.item_price  =  chips.item_price.str.replace('$','')

# %%
chips.item_price.astype(float)
chips.item_price=chips.item_price.astype(float)
chips.dtypes
#short for that,#chips.item_price=
len(chips.item_price)
# Out:
# 4622

# %%
chips.item_price=np.arange(0,4622)
chips.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-04e51581ea21> in <module>()
# ----> 1 chips.item_price=np.arange(0,4622)
#       2 chips.head()
#
# NameError: name 'np' is not defined

# %%
s=chips.item_name.str.contains('Chips')

# %%
chips_item=chips[s]

# %%
chips_item.shape
# Out:
# (1084, 5)

# %%
chips.choice_description.str.contains('Apple').fillna(False)
 
#for replacing nan then use this
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-6ba10dd441a5> in <module>()
# ----> 1 chips.choice_description.str.contains('Apple').fillna(False)
#       2
#       3 #for replacing nan then use this
#
# AttributeError: 'list' object has no attribute 'choice_description'

# %%
#len[chips.choice_description.str.contains('Apple').fillna(False)]
chips[chips.choice_description.str.contains('Apple').fillna(False)]
p=chips[chips.choice_description.str.contains('Apple').fillna(False)]
len(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-6e824d76c020> in <module>()
#       1 #len[chips.choice_description.str.contains('Apple').fillna(False)]
# ----> 2 chips[chips.choice_description.str.contains('Apple').fillna(False)]
#       3 p=chips[chips.choice_description.str.contains('Apple').fillna(False)]
#       4 len(p)
#
# AttributeError: 'list' object has no attribute 'choice_description'

# %%
x=chips[chips.choice_description.str.contains('salsa').dropna()(False)]#descripition is use when we have
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-149-b9144817d578> in <module>()
# ----> 1 x=chips[chips.choice_description.str.contains('salsa').dropna(False)]#descripition is use when we have
#
# AttributeError: 'list' object has no attribute 'choice_description'

# %%
header=['S.no','age','gender','occupation','zip code']

# %%
m=pd.read_table('http://bit.ly/movieusers',sep='|',names=header)
m.head()
# Out:
#    S.no  age gender  occupation zip code
# 0     1   24      M  technician    85711
# 1     2   53      F       other    94043
# 2     3   23      M      writer    32067
# 3     4   24      M  technician    43537
# 4     5   33      F       other    15213

# %%
m.columns
# Out:
# Index(['S.no', 'age', 'gender', 'occupation', 'zip code'], dtype='object')

# %%
m.columns.str.replace('gender','Gender')
m.head()
# Out:
#    S.no  age gender  occupation zip code
# 0     1   24      M  technician    85711
# 1     2   53      F       other    94043
# 2     3   23      M      writer    32067
# 3     4   24      M  technician    43537
# 4     5   33      F       other    15213

# %%
movies=pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.title.sort_values()
movies.duration.sort_values(ascending)
# Out:
# 542                   (500) Days of Summer
# 5                             12 Angry Men
# 201                       12 Years a Slave
# 698                              127 Hours
# 110                  2001: A Space Odyssey
# 910                                   2046
# 596                               21 Grams
# 624                              25th Hour
# 708                       28 Days Later...
# 60                                3 Idiots
# 225                                 3-Iron
# 570                                    300
# 555                           3:10 to Yuma
# 427           4 Months, 3 Weeks and 2 Days
# 824                                     42
# 597                                  50/50
# 203                                  8 1/2
# 170                       A Beautiful Mind
# 941                       A Bridge Too Far
# 571                           A Bronx Tale
# 266                      A Christmas Story
# 86                      A Clockwork Orange
# ...

# %%
movies .sort_values(['duration','genre'])

movies .sort_values('duration')
# Out:
#      star_rating                                          title  \
# 389          8.0                                         Freaks
# 338          8.0                            Battleship Potemkin
# 258          8.1                    The Cabinet of Dr. Caligari
# 293          8.1                                      Duck Soup
# 88           8.4                                        The Kid
# 742          7.6                                      Following
# 351          8.0                                   Frankenstein
# 938          7.4                            Alice in Wonderland
# 405          7.9                      The Bride of Frankenstein
# 303          8.0                 The Nightmare Before Christmas
# 713          7.6                                The Jungle Book
# 864          7.5                                          [Rec]
# 489          7.8                     The Triplets of Belleville
# 535          7.8                                          Zelig
# ...

# %%
movies[movies.genre.str.contains('Action')|movies.genre.str.contains('Comedy')]
# Out:
#      star_rating                                              title  \
# 3            9.0                                    The Dark Knight
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                          Star Wars
# 20           8.7                                         The Matrix
# 25           8.6                                  Life Is Beautiful
# 29           8.6                                        City Lights
# 35           8.6                                       Modern Times
# 36           8.6                                Saving Private Ryan
# 37           8.6                            Raiders of the Lost Ark
# 43           8.5                              The Dark Knight Rises
# 44           8.5                                          Gladiator
# 45           8.5                         Terminator 2: Judgment Day
# ...

# %%
a=movies[movies.genre.str.contains('Action')|movies.genre.str.contains('Comedy')]
a[(a.duration>=150)&(a.star_rating>=8)]
# Out:
#      star_rating                        title content_rating   genre  \
# 3            9.0              The Dark Knight          PG-13  Action
# 36           8.6          Saving Private Ryan              R  Action
# 43           8.5        The Dark Knight Rises          PG-13  Action
# 44           8.5                    Gladiator              R  Action
# 60           8.5                     3 Idiots          PG-13  Comedy
# 66           8.4          Munna Bhai M.B.B.S.      NOT RATED  Comedy
# 82           8.4                   Braveheart              R  Action
# 93           8.4  Dilwale Dulhania Le Jayenge      NOT RATED  Comedy
# 109          8.3               Dil Chahta Hai      NOT RATED  Comedy
# 129          8.3                          Ran              R  Action
# 135          8.3                         Heat              R  Action
# 183          8.2                  Underground      NOT RATED  Comedy
# 231          8.1                La Dolce Vita      NOT RATED  Comedy
# ...

# %%
movies.genre.value_counts(())
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
movies.genre.unique()
len(movies.genre.unique())
# Out:
# 16

# %%
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
#ese in &
movies.genre.isin(['Action','Comedy'])
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19      True
# 20      True
# 21     False
# 22     False
# 23     False
# 24     False
# 25      True
# 26     False
# 27     False
# 28     False
# 29      True
#        ...
# 949     True
# 950    False
# 951    False
# 952     True
# 953    False
# 954     True
# 955    False
# 956     True
# 957     True
# 958    False
# 959     True
# 960     True
# 961    False
# 962     True
# 963     True
# 964    False
# 965    False
# 966    False
# 967     True
# 968    False
# 969    False
# 970    False
# 971     True
# 972    False
# 973    False
# 974     True
# 975    False
# 976     True
# 977    False
# 978    False
# Name: genre, dtype: bool

# %%
movies .duration.sort_values()
# Out:
# 389     64
# 338     66
# 258     67
# 293     68
# 88      68
# 742     69
# 351     70
# 938     75
# 405     75
# 303     76
# 713     78
# 864     78
# 489     78
# 535     79
# 513     80
# 853     80
# 533     80
# 283     80
# 297     80
# 622     80
# 117     81
# 541     81
# 738     81
# 789     81
# 330     81
# 595     82
# 306     82
# 174     83
# 759     83
# 766     83
#       ...
# 361    181
# 166    182
# 109    183
# 245    184
# 132    186
# 611    187
# 318    188
# 184    188
# 89     189
# 316    189
# 40     189
# 671    191
# 220    191
# 424    193
# 620    194
# 8      195
# 385    197
# 335    197
# 2      200
# 7      201
# 630    202
# 767    205
# 17     207
# 204    212
# 85     216
# 445    220
# 142    224
# 78     229
# 157    238
# 476    242
# Name: duration, dtype: int64
